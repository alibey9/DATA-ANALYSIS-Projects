# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">"BIKE DEMAND VISUALIZATION CAPSTONE PROJECT" SOLUTION SESSION</p>
#
# ![image.jpg](https://i.ibb.co/c2rq4rT/Bike-Sharing.png)
#
# [Photo Credit: Thinking Neuron](https://thinkingneuron.com/bike-rental-demand-prediction-case-study-in-python/)

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CONTENT</p>
#
# * [ABOUT THE DATASET & CONTEXT](#0)
# * [ABOUT THE FEATURES](#00)
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#000)
# * [INSTRUCTIONS (Tasks in the Assignment)](#1)
# * [TASK 01 - READING THE DATASET](#2)
# * [TASK 02 - CHECKING MISSING VALUES & IF THERE ARE SOME DUBLICATE ROWS OR NOT](#3)
# * [TASK 03 - PLOTTING THE DISTRIBUTION OF VARIOUS DISCRETE FEATURES ON SEASON/HOLIDAY/WEEKEND/WEATHERCODE](#4)
# * [TASK 04 - LOOKING AT THE DATA TYPES OF EACH VARIABLE, TRANSFORM ``TIMESTAMP`` IN TYPE & SET IT AS INDEX](#5)
# * [TASK 05 - MAKING FEATURE ENGINEERING. EXTRACTING NEW COLUMNS (DAY OF WEEK, DAY OF MONTH, HOUR, MONTH, SEASON, YEAR ETC.](#6)
# * [TASK 06 - VISUALIZING THE CORRELATION WITH A HEATMAP](#7)
# * [TASK 07 - VISUALIZING THE CORRELATION OF THE TARGET VARIABLE & THE OTHER FEATURES WITH BARPLO](#8)
# * [TASK 08 - PLOTTING BIKE SHARES OVER TIME BY USING LINEPLOT](#9)
# * [TASK 09 - PLOTTING BIKE SHARES BY MONTHS & YEAR_OF_MONTH (USE LINEPLOT, POINTPOT, BARPLOT)](#10)
# * [TASK 10 - PLOTTING BIKE SHARES BY HOURS ON (HOLIDAYS, WEEKEND, SEASON)](#11)
# * [TASK 11 - PLOTTING BIKE SHARES BY DAY OF WEEK](#12)
# * [TASK 12 - PLOTTING BIKE SHARES BY DAY OF MONTH](#13)
# * [TASK 13 - PLOTTING BIKE SHARES BY YEAR & PLOTTING BIKE SHARES ON HOLIDAYS BY SEASON](#14)
# * [TASK 14 - VISUALIZING THE DISTRIBUTION OF BIKE SHARES BY WEEKDAY-WEEKEND WITH USING PIECHART & BARPLOT](#15)
# * [TASK 15 - PLOTTING THE DISTRIBUTION OF WEATHER CODE BY SEASON](#16)
# * [THE END OF THE CAPSTONE PROJECT](#17)

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">ABOUT THE DATASET & CONTEXT</p>
#
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">ABOUT THE FEATURES</p>
#
# <a id="00"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **- ``timestamp``** - timestamp field for grouping the data<br>
# **- ``cnt``** - the count of a new bike shares<br>
# **- ``t1``** - real temperature in C<br>
# **- ``t2``** - temperature in C “feels like”<br>
# **- ``hum``** - humidity in percentage<br>
# **- ``wind_speed``** - wind speed in km/h<br>
# **- ``weather_code``** - category of the weather<br>
# **- ``is_holiday``** - boolean field - 1 holiday / 0 non holiday<br>
# **- ``is_weekend``** - boolean field - 1 if the day is weekend<br>
# **- ``season``** - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.<br>
#
# **"weather_code" category description:**<br>
# **``1``** = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity<br>
# **``2``** = scattered clouds / few clouds<br>
# **``3``** = Broken clouds<br>
# **``4``** = Cloudy<br>
# **``7``** = Rain/ light Rain shower/ Light rain<br>
# **``10``** = rain with thunderstorm<br>
# **``26``** = snowfall<br>
# **``94``** = Freezing Fog<br>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">INSTRUCTIONS (Tasks in the Assignment)</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# **In this assignment you're required to handle with the following tasks:**
#
# - **Task 01.** Reading the dataset<br>
# - **Task 02.** Check missing values and if there are any dublicate rows or not.<br>
# - **Task 03.** Plotting the distribution of various discrete features on (Season, holiday, weekend and weathercode)<br>
# - **Task 04.** Looking at the data type of each variable, transform timestamp in type, and set it as index.<br>
# - **Task 05.** Making feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)<br>
# - **Task 06.** Visualizing the correlation with a heatmap<br>
# - **Task 07.** Visualizing the correlation of the target variable and the other features with barplot<br>
# - **Task 08.** Plotting bike shares over time use lineplot<br>
# - **Task 09.** Plotting bike shares by months and year_of_month (use lineplot, pointplot, barplot)<br>
# - **Task 10.** Plotting bike shares by hours on (holidays, weekend, season)<br>
# - **Task 11.** Plotting bike shares by day of week<br>
# - **Task 12.** Plotting bike shares by day of month<br>
# - **Task 13.** Plotting bike shares by year & Plotting bike shares on holidays by seasons<br>
# - **Task 14.** Visualizing the distribution of bike shares by weekday/weekend with piechart and barplot<br>
# - **Task 15.** Plotting the distribution of weather code by seasons<br>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK</p>
#
# <a id="000"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams

# seaborn grafiklerimizin boyutları için ön ayar!!!!!!!
sns.set_theme(rc={'figure.figsize':(15,8)})
sns.set_theme(style="darkgrid");


import lux

import warnings
warnings.filterwarnings("ignore")

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 01 - READING THE DATASET</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **Now Let us first try to load and read the PoliceKillingsUS dataset. [SOURCE](https://towardsdatascience.com/learn-how-to-read-data-into-a-pandas-dataframe-in-5-minutes-122af8e0b9db) for learning how to read data into a Pandas DataFrame in 5 minutes.**

# %%
df0 = pd.read_csv('store_sharing.csv')
df = df0.copy()
df.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 02 - CHECKING MISSING VALUES & IF THERE ARE SOME DUBLICATE ROWS OR NOT</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.duplicated()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.duplicated().value_counts()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df[df.duplicated()].shape
# Out:
# (0, 10)

# %%
df.isnull()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.isnull().sum()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.sample(10)
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 03 - PLOTTING THE DISTRIBUTION OF VARIOUS DISCRETE FEATURES ON SEASON-HOLIDAY-WEEKEND-WEATHERCODE</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df['season'].value_counts()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df['season'].value_counts().index
# Out:
# Float64Index([0.0, 1.0, 3.0, 2.0], dtype='float64')

# %%
df['season'].value_counts().values
# Out:
# array([4394, 4387, 4330, 4303], dtype=int64)

# %%
ax= df["season"].value_counts().plot(kind="bar", x=df['season'].value_counts().index, y=df['season'].value_counts().values)
ax=sns.countplot(data=df, x='season')
for i in ax.containers:
    ax.bar_label(i, fontsize=20);

# %%
fig, ax= plt.subplots()

ax=sns.countplot(data=df, x='season')
for i in ax.containers:
    ax.bar_label(i, fontsize=20);

# %% [markdown]
# [For a Better Understanding of What ``for loop`` does ==> Visit Here](https://medium.com/@dey.mallika/transform-your-graphs-with-seaborn-ea4fa8e606a6)

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
fig, ax = plt.subplots()

chart = sns.countplot(data=df, x='is_holiday');

chart.bar_label(chart.containers[0], fontsize=20);

# %%
fig, ax = plt.subplots()

ax=sns.countplot(data=df, x='is_holiday')

for i in ax.containers:
    ax.bar_label(i, fontsize=20);

# %%
fig, ax = plt.subplots()

ax=sns.countplot(data=df, x='is_weekend')

for i in ax.containers:
    ax.bar_label(i, fontsize=20);

# %% [markdown]
# **"weather_code" category description:**<br>
# **``1``** = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity<br>
# **``2``** = scattered clouds / few clouds<br>
# **``3``** = Broken clouds<br>
# **``4``** = Cloudy<br>
# **``7``** = Rain/ light Rain shower/ Light rain<br>
# **``10``** = rain with thunderstorm<br>
# **``26``** = snowfall<br>
# **``94``** = Freezing Fog<br>

# %%
fig, ax = plt.subplots()

ax=sns.countplot(data=df, x='weather_code')

for i in ax.containers:
    ax.bar_label(i, fontsize=20);

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 04 - LOOKING AT THE DATA TYPES OF EACH VARIABLE, TRANSFORM ``TIMESTAMP`` IN TYPE & SET IT AS INDEX</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()
# Out:
# <class 'lux.core.frame.LuxDataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
type(df['timestamp'])
# Out:
# lux.core.series.LuxSeries

# %%
df['timestamp']= pd.to_datetime(df['timestamp'])
df['timestamp']
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
type(df['timestamp'])
# Out:
# lux.core.series.LuxSeries

# %%
df.info()
# Out:
# <class 'lux.core.frame.LuxDataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df.set_index('timestamp', inplace=True)

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# - We have a 2-year timestamp, so let us do Feature Engineering by using `year, month, day_of_month, day_of_week, hour`

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 05 - MAKING FEATURE ENGINEERING. EXTRACTING NEW COLUMNS (DAY OF WEEK, DAY OF MONTH, HOUR, MONTH, SEASON, YEAR ETC.</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-04 00:00:00', '2015-01-04 01:00:00',
#                '2015-01-04 02:00:00', '2015-01-04 03:00:00',
#                '2015-01-04 04:00:00', '2015-01-04 05:00:00',
#                '2015-01-04 06:00:00', '2015-01-04 07:00:00',
#                '2015-01-04 08:00:00', '2015-01-04 09:00:00',
#                ...
#                '2017-01-03 14:00:00', '2017-01-03 15:00:00',
#                '2017-01-03 16:00:00', '2017-01-03 17:00:00',
#                '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#                '2017-01-03 20:00:00', '2017-01-03 21:00:00',
#                '2017-01-03 22:00:00', '2017-01-03 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=17414, freq=None)

# %%
df.index.year
# Out:
# Int64Index([2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015,
#             ...
#             2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017],
#            dtype='int64', name='timestamp', length=17414)

# %%
df.index.max() - df.index.min()
# Out:
# Timedelta('730 days 23:00:00')

# %% [markdown]
# **strftime()**

# %%
f = lambda x: x.strftime('%Y-%m')

# %%
f
# Out:
# <function __main__.<lambda>(x)>

# %%
f(df.index)
# Out:
# Index(['2015-01', '2015-01', '2015-01', '2015-01', '2015-01', '2015-01',
#        '2015-01', '2015-01', '2015-01', '2015-01',
#        ...
#        '2017-01', '2017-01', '2017-01', '2017-01', '2017-01', '2017-01',
#        '2017-01', '2017-01', '2017-01', '2017-01'],
#       dtype='object', name='timestamp', length=17414)

# %%
df['year_month'] = f(df.index)

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.info()
# Out:
# <class 'lux.core.frame.LuxDataFrame'>
# DatetimeIndex: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  float64
#  6   is_holiday    17414 non-null  float64
#  7   is_weekend    17414 non-null  float64
#  8   season        17414 non-null  float64
#  9   year_month    17414 non-null  object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
f = lambda x: x.strftime("%Y-%m")

df["year_month"]=f(df.index)
df["year"] = df.index.year
df["month"] = df.index.month
df["day_of_month"] = df.index.day
df["day_of_week"] = df.index.dayofweek
df["hour"] = df.index.hour

# %%
df.info()
# Out:
# <class 'lux.core.frame.LuxDataFrame'>
# DatetimeIndex: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  float64
#  6   is_holiday    17414 non-null  float64
#  7   is_weekend    17414 non-null  float64
#  8   season        17414 non-null  float64
#  9   year_month    17414 non-null  object
#  10  year          17414 non-null  int64
#  11  month         17414 non-null  int64
#  12  day_of_month  17414 non-null  int64
#  13  day_of_week   17414 non-null  int64
#  14  hour          17414 non-null  int64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 2.1+ MB

# %%
df.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# ***alternative solition***
# ```
# import datetime as dt
# df2  =pd.read_csv('store_sharing.csv')
# df2['timestamp'] =  pd.to_datetime(df2['timestamp'], infer_datetime_format=True)
#
# df2["yıl"] = df2['timestamp'].dt.year
# df2["ay"] = df2['timestamp'].dt.month
# df2["gun"] = df2['timestamp'].dt.day
# df2["day_of_week"] = df2['timestamp'].dt.dayofweek
# df2["saat"] = df2['timestamp'].dt.hour
#
# df2["year-month"] = df2['timestamp'].apply(lambda x: x.strftime('%Y-%m'))
#
# df2.set_index('timestamp',inplace=True)
# df2
# ```

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 06 - VISUALIZING THE CORRELATION WITH A HEATMAP</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.corr()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
plt.figure(figsize=(18,12))

sns.heatmap(df.corr(), annot=True, cmap='coolwarm');

# %%
df_cnt_corr = df.corr()[['cnt']]
df.corr()[['cnt']]
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df_corr = df.corr()[["cnt"]].sort_values(by="cnt", ascending=False)

# %%
plt.figure(figsize=(2, 7))
sns.heatmap(df_corr, annot= True, cmap="coolwarm", vmin = -1, vmax=1);

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr()[['cnt']], annot=True, cmap='coolwarm');

# %% [markdown]
# **The possible value of the palette/cmap are:**
#
# ‘Accent’, ‘Accent_r’, ‘Blues’, ‘Blues_r’, ‘BrBG’, ‘BrBG_r’, ‘BuGn’, ‘BuGn_r’, ‘BuPu’, ‘BuPu_r’, ‘CMRmap’, ‘CMRmap_r’, ‘Dark2’, ‘Dark2_r’, ‘GnBu’, ‘GnBu_r’,  ‘Greens’, ‘Greens_r’, ‘Greys’, ‘Greys_r’, ‘OrRd’, ‘OrRd_r’, ‘Oranges’, ‘Oranges_r’,  ‘PRGn’, ‘PRGn_r’, ‘Paired’, ‘Paired_r’, ‘Pastel1’, ‘Pastel1_r’, ‘Pastel2’,  ‘Pastel2_r’, ‘PiYG’, ‘PiYG_r’, ‘PuBu’, ‘PuBuGn’, ‘PuBuGn_r’, ‘PuBu_r’, ‘PuOr’, ‘PuOr_r’, ‘PuRd’, ‘PuRd_r’, ‘Purples’, ‘Purples_r’, ‘RdBu’, ‘RdBu_r’, ‘RdGy’, ‘RdGy_r’, ‘RdPu’, ‘RdPu_r’, ‘RdYlBu’, ‘RdYlBu_r’, ‘RdYlGn’, ‘RdYlGn_r’, ‘Reds’, ‘Reds_r’, ‘Set1’, ‘Set1_r’, ‘Set2’, ‘Set2_r’, ‘Set3’, ‘Set3_r’, ‘Spectral’, ‘Spectral_r’, ‘Wistia’, ‘Wistia_r’, ‘YlGn’, ‘YlGnBu’, ‘YlGnBu_r’, ‘YlGn_r’, ‘YlOrBr’, ‘YlOrBr_r’, ‘YlOrRd’, ‘YlOrRd_r’, ‘afmhot’, ‘afmhot_r’, ‘autumn’, ‘autumn_r’, ‘binary’, ‘binary_r’,  ‘bone’, ‘bone_r’, ‘brg’, ‘brg_r’, ‘bwr’, ‘bwr_r’, ‘cividis’, ‘cividis_r’, ‘cool’, ‘cool_r’,  ‘coolwarm’, ‘coolwarm_r’, ‘copper’, ‘copper_r’, ‘cubehelix’, ‘cubehelix_r’, ‘flag’, ‘flag_r’,  ‘gist_earth’, ‘gist_earth_r’, ‘gist_gray’, ‘gist_gray_r’, ‘gist_heat’, ‘gist_heat_r’, ‘gist_ncar’,  ‘gist_ncar_r’, ‘gist_rainbow’, ‘gist_rainbow_r’, ‘gist_stern’, ‘gist_stern_r’, ‘gist_yarg’,  ‘gist_yarg_r’, ‘gnuplot’, ‘gnuplot2’, ‘gnuplot2_r’, ‘gnuplot_r’, ‘gray’, ‘gray_r’, ‘hot’, ‘hot_r’,  ‘hsv’, ‘hsv_r’, ‘icefire’, ‘icefire_r’, ‘inferno’, ‘inferno_r’, ‘jet’, ‘jet_r’, ‘magma’, ‘magma_r’,  ‘mako’, ‘mako_r’, ‘nipy_spectral’, ‘nipy_spectral_r’, ‘ocean’, ‘ocean_r’, ‘pink’, ‘pink_r’,  ‘plasma’, ‘plasma_r’, ‘prism’, ‘prism_r’, ‘rainbow’, ‘rainbow_r’, ‘rocket’, ‘rocket_r’,  ‘seismic’, ‘seismic_r’, ‘spring’, ‘spring_r’, ‘summer’, ‘summer_r’, ‘tab10’, ‘tab10_r’,’tab20′, ‘tab20_r’, ‘tab20b’, ‘tab20b_r’, ‘tab20c’, ‘tab20c_r’, ‘terrain’, ‘terrain_r’, ‘turbo’,  ‘turbo_r’, ‘twilight’, ‘twilight_r’, ‘twilight_shifted’, ‘twilight_shifted_r’, ‘viridis’,  ‘viridis_r’, ‘vlag’, ‘vlag_r’, ‘winter’, ‘winter_r’
#
# [Source](https://www.geeksforgeeks.org/seaborn-color-palette/)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 07 - VISUALIZING THE CORRELATION OF THE TARGET VARIABLE & THE OTHER FEATURES WITH BARPLOT</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.corr()['cnt'].sort_values().plot.barh();

# %%
df.corr()['cnt'].sort_values().plot.bar();

# %% [markdown]
# ***Alternative Solution***
#
# ```
# x = df.corr()["cnt"].sort_values(ascending=False).index
# y = df.corr()["cnt"].sort_values(ascending=False).values
# sns.barplot(y,x, orient="h", color="b" )
# ```

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 08 - PLOTTING BIKE SHARES OVER TIME BY USING LINEPLOT</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.head(1)
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
plt.figure(figsize=(18,5))
sns.lineplot(data=df, x= df.index, y='cnt');

# %% [markdown]
# ![Screenshot%202022-05-23%20175710.png](attachment:Screenshot%202022-05-23%20175710.png)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 09 - PLOTTING BIKE SHARES BY MONTHS & YEAR_OF_MONTH (USE LINEPLOT, POINTPOT, BARPLOT)</p>
#
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df.groupby('year_month').cnt.sum()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
pd.DataFrame(df.groupby('year_month').cnt.sum())
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df_cnt_sum= pd.DataFrame(df.groupby('year_month').cnt.sum())

# %%
plt.figure(figsize=(25,5))

sns.lineplot(data=df_cnt_sum, x='year_month', y='cnt');

# %%
plt.figure(figsize=(25,5))

sns.lineplot(data=df_cnt_sum, x='year_month', y='cnt')

plt.ticklabel_format(style='plain', axis='y')

plt.xticks(rotation=90);

# %%
df_month = df.groupby("month").cnt.sum()
df_month
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
plt.figure(figsize=(25,5))

sns.lineplot(x = df_month.index, y = df_month.values, data = df_month) 

plt.ticklabel_format(style="plain", axis= "y")

# %%
df.groupby("month")["cnt"].mean()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
sns.pointplot(x="month", y ="cnt", data=df);

# %%
plt.figure(figsize=(14, 6))

sns.barplot(x="month", y ="cnt", data=df, ci= 60);

# %%
plt.figure(figsize=(14, 6))

ax = sns.barplot(x="month", y ="cnt", data=df, estimator = sum, ci = None)

ax.bar_label(ax.containers[0]);

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 10 - PLOTTING BIKE SHARES BY HOURS ON (HOLIDAYS, WEEKEND, SEASON)</p>
#
# <a id="11"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
plt.figure(figsize=(18, 6))

sns.lineplot(x="hour", y= "cnt", data=df, hue= "is_weekend")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize=(18, 6))

sns.lineplot(x="hour", y= "cnt", data=df, hue= "season")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, figsize=(25, 25))

sns.pointplot(data=df, x='hour', y='cnt', ax=ax1)
sns.pointplot(data=df, x='hour', y='cnt',hue="is_holiday", ax=ax2)
sns.pointplot(data=df, x='hour', y='cnt',hue="is_weekend", ax=ax3)
sns.pointplot(data=df, x='hour', y='cnt',hue="season", ax=ax4)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 11 - PLOTTING BIKE SHARES BY DAY OF WEEK</p>
#
# <a id="12"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - You may want to see whether it is a holiday or not

# %%
df.head()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
sns.barplot(data=df, x="day_of_week", y="cnt", hue="is_weekend");

# %%
fig, (ax1, ax2,) = plt.subplots(nrows=2, figsize=(18, 15))

sns.pointplot(data=df, x='day_of_week', y='cnt', ax=ax1)
sns.pointplot(data=df, x='day_of_week', y='cnt',hue="season", ax=ax2)
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='cnt'>

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 12 - PLOTTING BIKE SHARES BY DAY OF MONTH</p>
#
# <a id="13"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
plt.figure(figsize=(15, 5))

sns.lineplot(x='day_of_month', y='cnt', data=df)
pd.DataFrame(df.groupby('day_of_month').cnt.mean().apply(lambda x: round(x))).T
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 13 - PLOTTING BIKE SHARES BY YEAR & PLOTTING BIKE SHARES ON HOLIDAYS BY SEASON</p>
#
# <a id="14"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
sns.barplot(x="year", y="cnt", data=df);

# %%
sns.barplot(x='season', y='cnt', data=df);

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 14 - VISUALIZING THE DISTRIBUTION OF BIKE SHARES BY WEEKDAY-WEEKEND WITH USING PIECHART & BARPLOT</p>
#
# <a id="15"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df["is_weekend"].value_counts()
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
df["is_weekend"].value_counts().values
# Out:
# array([12444,  4970], dtype=int64)

# %%
fig, ax=plt.subplots(figsize=(8,8))

explode = (0, 0.1)
ax= ax.pie(x=df["is_weekend"].value_counts().values, labels=["weekday", "weekend"],
      explode=explode,
      autopct="%.1f%%")

plt.show()

# %% [markdown]
# ***Alternative Solition***

# %%
ax=sns.countplot(x="is_weekend", data=df)

for i in ax.containers:
    ax.bar_label(i, fontsize=20)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">TASK 15 - PLOTTING THE DISTRIBUTION OF WEATHER CODE BY SEASON</p>
#
# <a id="16"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ax = sns.countplot(x="weather_code", data=df)

for i in ax.containers:
    ax.bar_label(i, fontsize=20)

# %%
sns.catplot(x="weather_code", data=df, kind="count", col="season");

# %%
df["weather_code2"] = df["weather_code"].astype('O')

# %%
g = sns.catplot(x="weather_code2", data = df, kind="count", hue="season")

g.fig.set_figwidth(15)
g.fig.set_figheight(8)

# %% [markdown]
# ## BONUS

# %%
# Thu Lux is an extra visualization Libarary 
# which is, at the begining of your analysis, beneficial to get first insight about the data before going further.

import lux
# !pip install lux-api
# !jupyter nbextension install --py luxwidget
# !jupyter nbextension enable --py luxwidget

# %%
# !pip install lux-api
# Out:
# Requirement already satisfied: lux-api in c:\users\mehme\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (0.24.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (1.20.3)
# Requirement already satisfied: altair>=4.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (4.2.0)
# Requirement already satisfied: pandas in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (1.3.4)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (5.9.1)
# Requirement already satisfied: iso3166 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (2.0.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (3.4.3)
# Requirement already satisfied: sh in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (1.14.2)
# Requirement already satisfied: lux-widget>=0.1.4 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (0.1.11)
# Requirement already satisfied: autopep8>=1.5 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (1.5.7)
# Requirement already satisfied: scipy>=1.3.3 in c:\users\mehme\anaconda3\lib\site-packages (from lux-api) (1.7.1)
# Requirement already satisfied: jinja2 in c:\users\mehme\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mehme\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (3.2.0)
# Requirement already satisfied: toolz in c:\users\mehme\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (0.11.1)
# Requirement already satisfied: entrypoints in c:\users\mehme\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (0.3)
# Requirement already satisfied: toml in c:\users\mehme\anaconda3\lib\site-packages (from autopep8>=1.5->lux-api) (0.10.2)
# Requirement already satisfied: pycodestyle>=2.7.0 in c:\users\mehme\anaconda3\lib\site-packages (from autopep8>=1.5->lux-api) (2.7.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\mehme\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\mehme\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.18.0)
# Requirement already satisfied: setuptools in c:\users\mehme\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (58.0.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mehme\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (21.2.0)
# Requirement already satisfied: notebook>=4.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from lux-widget>=0.1.4->lux-api) (6.4.5)
# Requirement already satisfied: ipywidgets>=7.5.0 in c:\users\mehme\anaconda3\lib\site-packages (from lux-widget>=0.1.4->lux-api) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mehme\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (7.29.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mehme\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.4.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\mehme\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.1.12)
# Requirement already satisfied: pygments in c:\users\mehme\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.10.0)
# Requirement already satisfied: decorator in c:\users\mehme\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.0)
# Requirement already satisfied: backcall in c:\users\mehme\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: colorama in c:\users\mehme\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\mehme\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\mehme\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mehme\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\mehme\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mehme\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\mehme\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mehme\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (228)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mehme\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mehme\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\mehme\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mehme\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (1.3.1)
# Requirement already satisfied: argon2-cffi in c:\users\mehme\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\mehme\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mehme\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\mehme\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.11.0)
# Requirement already satisfied: nbconvert in c:\users\mehme\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.1.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mehme\anaconda3\lib\site-packages (from pandas->lux-api) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\mehme\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from scikit-learn>=0.22->lux-api) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\mehme\anaconda3\lib\site-packages (from scikit-learn>=0.22->lux-api) (1.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\mehme\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\mehme\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\mehme\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mehme\anaconda3\lib\site-packages (from jinja2->altair>=4.0.0->lux-api) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mehme\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.8.4)
# Requirement already satisfied: testpath in c:\users\mehme\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\mehme\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mehme\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.4.3)
# Requirement already satisfied: bleach in c:\users\mehme\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mehme\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mehme\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.2)
# Requirement already satisfied: async-generator in c:\users\mehme\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\mehme\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\mehme\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.1)
# Requirement already satisfied: packaging in c:\users\mehme\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.0)

# %%
# !jupyter nbextension install --py luxwidget
# Out:
# Installing C:\Users\mehme\anaconda3\lib\site-packages\luxwidget\nbextension/static -> luxwidget
# Up to date: C:\ProgramData\jupyter\nbextensions\luxwidget\extension.js
# Up to date: C:\ProgramData\jupyter\nbextensions\luxwidget\index.js
# Up to date: C:\ProgramData\jupyter\nbextensions\luxwidget\index.js.map
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable luxwidget --py

# %%
# !jupyter nbextension enable --py luxwidget
# Out:
# Enabling notebook extension luxwidget/extension...
#       - Validating: ok

# %%
import lux

# %%
import luxwidget

# %%
df
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">THE END OF THE CAPSTONE PROJECT</p>
#
# <a id="17"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
